# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv("analog-data.csv")

# %%
df
# Out:
#     b'MQ135 RAW VALUE  DESIRED PPM  MQ2 RAW VALUE  LPG(PPM)  CO(PPM)  \
# 0                 557        17.83            116      0.01     0.01
# 1                 573        21.50            123      0.01     0.01
# 2                 580        23.35            128      0.02     0.02
# 3                 575        22.01            131      0.02     0.02
# 4                 582        23.90            131      0.02     0.02
# 5                 566        19.80            129      0.02     0.02
# 6                 576        22.27            128      0.02     0.02
# 7                 575        22.01            125      0.02     0.02
# 8                 576        22.27            124      0.02     0.01
# 9                 565        19.57            122      0.02     0.01
# 10                546        15.68            122      0.02     0.01
#
#     SMOKE(PPM)\r\
# 0            0.03
# 1            0.04
# 2            0.06
# 3            0.06
# 4            0.06
# 5            0.06
# ...

# %%
sns.lmplot(x='DESIRED PPM',y='CO(PPM)',data=df)

# %%
df.corr()
# Out:
#                    b'MQ135 RAW VALUE  DESIRED PPM  MQ2 RAW VALUE  LPG(PPM)  \
# b'MQ135 RAW VALUE           1.000000     0.997942       0.661810  0.233607
# DESIRED PPM                 0.997942     1.000000       0.675459  0.252038
# MQ2 RAW VALUE               0.661810     0.675459       1.000000  0.634829
# LPG(PPM)                    0.233607     0.252038       0.634829  1.000000
# CO(PPM)                     0.594555     0.602216       0.830996  0.516398
# SMOKE(PPM)\r\               0.686270     0.698017       0.959512  0.677003
#
#                     CO(PPM)  SMOKE(PPM)\r\
# b'MQ135 RAW VALUE  0.594555       0.686270
# DESIRED PPM        0.602216       0.698017
# MQ2 RAW VALUE      0.830996       0.959512
# LPG(PPM)           0.516398       0.677003
# CO(PPM)            1.000000       0.874007
# SMOKE(PPM)\r\      0.874007       1.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-8f86c0513087> in <module>
# ----> 1 a=df[1][1]
#
# ...

# %%
sns.heatmap(df.corr(),annot=True)

# %%
import matplotlib.pyplot as plt

# %%
g = sns.PairGrid(df)
g.map(plt.scatter)

# %%
g = g.map(plt.hist, "LPG(PPM)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ccad1b2010c8> in <module>
# ----> 1 g = g.map(plt.hist, "LPG(PPM)")
#
# TypeError: map() takes 2 positional arguments but 3 were given

# %%
plt.plot(x, y, label = "line 1", linestyle="-")
plt.plot(y, x, label = "line 2", linestyle="--")
plt.plot(x, np.sin(x), label = "curve 1", linestyle="-.")
plt.plot(x, np.cos(x), label = "curve 2", linestyle=":")
plt.legend()
plt.show()b

# %%
sns.boxplot(x="LPG(PPM)", y="CO(PPM)", data=df,palette='rainbow')

# %%
sns.distplot(df["DESIRED PPM"],kde=False,bins=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-81f1805838c6> in <module>
# ----> 1 sns.distplot(df["DESIRED PPM"],kde=False,bins=30,grid=True)
#
# TypeError: distplot() got an unexpected keyword argument 'grid'

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df=pd.read_csv("analogdata5.csv")

# %%
df.head(6)
# Out:
#    CO2(PPM)  AQI(PPM)  CO(PPM)  LPG(PPM)  BUTANE(PPM)  SMOKE(PPM)  TEMP DAYS
# 0       688     88.59      256      0.01          0.0        0.02    36  MON
# 1       679     78.76      253      0.01          0.0        0.02    36  MON
# 2       671     71.04      250      0.01          0.0        0.02    36  MON
# 3       663     64.15      249      0.01          0.0        0.02    36  MON
# 4       654     57.26      246      0.01          0.0        0.02    36  MON
# 5       648     53.11      241      0.01          0.0        0.01    36  MON

# %%
df.set_index('DAYS')
# Out:
#       CO2(PPM)  AQI(PPM)  CO(PPM)  LPG(PPM)  BUTANE(PPM)  SMOKE(PPM)  TEMP
# DAYS
# MON        688     88.59      256      0.01         0.00        0.02    36
# MON        679     78.76      253      0.01         0.00        0.02    36
# MON        671     71.04      250      0.01         0.00        0.02    36
# MON        663     64.15      249      0.01         0.00        0.02    36
# MON        654     57.26      246      0.01         0.00        0.02    36
# ...        ...       ...      ...       ...          ...         ...   ...
# SUN        579     23.07      390      0.01         0.01        0.03    37
# SUN        576     22.27      390      0.01         0.01        0.03    37
# SUN        575     22.01      390      0.01         0.01        0.03    37
# SUN        575     22.01      390      0.01         0.01        0.03    37
# SUN        574     21.75      391      0.01         0.01        0.03    37
#
# [3969 rows x 7 columns]

# %%
df.plot(kind='area', stacked=False)

# %%
df.plot(kind='line', stacked=False)

# %%
df.groupby('DAYS').median()
# Out:
#       CO2(PPM)  AQI(PPM)  CO(PPM)  LPG(PPM)  BUTANE(PPM)  SMOKE(PPM)  TEMP
# DAYS
# FRI        555     17.42      213       0.0          0.0        0.00    36
# MON        589     25.97      165       0.0          0.0        0.00    39
# SAT        446      4.90      161       0.0          0.0        0.00    40
# SUN        601     29.95      403       0.0          0.0        0.01    37
# THU        504      9.64      141       0.0          0.0        0.00    37
# TUE        621     38.11      167       0.0          0.0        0.00    39
# WED        364      1.81       83       0.0          0.0        0.00    34

# %%
sns.boxplot(x='DAYS',y='TEMP',data=df)

# %%
sns.boxplot(x='DAYS',y='CO(PPM)',data=df)

# %%
sns.boxplot(x='DAYS',y='AQI(PPM)',data=df)

# %%
sns.boxplot(x='DAYS',y='CO2(PPM)',data=df)

# %%
sns.distplot(df['CO2(PPM)'])

# %%
sns.distplot(df['CO(PPM)'])

# %%
sns.distplot(df['AQI(PPM)'])

# %%
sns.distplot(df['TEMP'])

# %%
sns.distplot(df['SMOKE(PPM)'])

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(df['DAYS'],df['AQI(PPM)'])
axes.plot(df['DAYS'],df['CO2(PPM)'])
axes.plot(df['DAYS'],df['CO(PPM)'])
axes.plot(df['DAYS'],df['TEMP'])

# %%
a=df['CO2(PPM)'].mean()

# %%
b=df['AQI(PPM)'].mean()

# %%
c=df['CO(PPM)'].mean()

# %%
d=df['TEMP'].mean()

# %%
x=[a,b,c,d]
y=['CO2(PPM)','AQI(PPM)','CO(PPM)','TEMP']

# %%
ab=pd.DataFrame(data=x)

# %%
ab
# Out:
#             0
# 0  529.495087
# 1   20.280988
# 2  201.539934
# 3   37.270849

# %%
x
# Out:
# [529.4950869236584, 20.28098765432106, 201.53993449231544, 37.27084908037289]

# %%
y
# Out:
# ['CO2(PPM)', 'AQI(PPM)', 'CO(PPM)', 'TEMP']

# %%
a

# %%
ab['y']=['CO2(PPM)','AQI(PPM)','CO(PPM)','TEMP']

# %%
ab
# Out:
#             0         y
# 0  529.495087  CO2(PPM)
# 1   20.280988  AQI(PPM)
# 2  201.539934   CO(PPM)
# 3   37.270849      TEMP

# %%
ab.drop(0,axis=1,inplace=True)

# %%
ab['x']=[528.5879038317055,21.049628099173734,158.2396694214876,36.72276483846732]

# %%
ab
# Out:
#           y           x
# 0  CO2(PPM)  528.587904
# 1  AQI(PPM)   21.049628
# 2   CO(PPM)  158.239669
# 3      TEMP   36.722765

# %%
m=ab[ab['x']<100]

# %%
m
# Out:
#           y          x
# 1  AQI(PPM)  21.049628
# 3      TEMP  36.722765

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(ab['y'],ab['x'])

# %%
sns.boxplot(x=m['y'],y=m['x'],data=m)

# %%
# Out:
#           y           x
# 1  AQI(PPM)   21.049628
# 2   CO(PPM)  158.239669
# 3      TEMP   36.722765

# %%
arr=np.arange(0,600,100)

# %%
arr
# Out:
# array([  0, 100, 200, 300, 400, 500])

# %%
sns.boxplot(x='y',y='x',data=m)
