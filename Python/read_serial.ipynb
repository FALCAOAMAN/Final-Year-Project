# %%
import serial
import time 
import datetime

# %%
arduino_port = "COM4" #serial port of Arduino
baud = 9600 #arduino uno runs at 9600 baud
fileName="analog-data7.csv" #name of the CSV file generated

# %%
ser = serial.Serial(arduino_port, baud)
print("Connected to Arduino port:" + arduino_port)
file = open(fileName, "a")
print("Created file")
# Out:
# Connected to Arduino port:COM4
# Created file

# %%
#display the data to the terminal
getData=str(ser.readline())
data=getData[0:][:-2]
print(data)

#add the data to the file
file = open(fileName, "a") #append the data to the file
file.write(data+"\n") #write data with a newline

#close out the file
file.close()
# Out:
# b'MQ135 RAW VALUE,DESIRED PPM,MQ2 RAW VALUE,LPG(PPM),CO(PPM),SMOKE(PPM),TEMP(C)\r\

# %%
 samples = 200 #how many samples to collect
print_labels = False
line = 0 #start at 0 because our header is 0 (not real data)
while line <= samples:
    # incoming = ser.read(9999)
    # if len(incoming) > 0:
    if print_labels:
        if line==0:
            print("Printing Column Headers")
        else:
            print("Line " + str(line) + ": writing...")
    getData=str(ser.readline().decode())
    data=getData[0:][:-2]
    print(data)

    file = open(fileName, "a")
    file.write(data + "\n") #write data with a newline
    line = line+1

print("Data collection complete!")
file.close()
# Out:
# 572,21.25,379,0.01,0.00,0.02,37
# 575,22.01,380,0.01,0.01,0.02,37
# 576,22.27,380,0.01,0.01,0.02,37
# 574,21.75,380,0.01,0.01,0.02,37
# 572,21.25,380,0.01,0.01,0.02,37
# 573,21.50,380,0.01,0.01,0.02,37
# 572,21.25,380,0.01,0.01,0.02,37
# 571,21.00,381,0.01,0.01,0.02,37
# 570,20.76,381,0.01,0.01,0.02,37
# 569,20.51,381,0.01,0.01,0.02,37
# 569,20.51,382,0.01,0.01,0.02,37
# 571,21.00,382,0.01,0.01,0.02,37
# 569,20.51,383,0.01,0.01,0.02,37
# 568,20.27,382,0.01,0.01,0.02,37
# 568,20.27,382,0.01,0.01,0.02,37
# 566,19.80,382,0.01,0.01,0.02,37
# 566,19.80,382,0.01,0.01,0.02,37
# 564,19.35,382,0.01,0.01,0.02,37
# 563,19.12,383,0.01,0.01,0.02,37
# 561,18.68,382,0.01,0.01,0.02,37
# 561,18.68,383,0.01,0.01,0.02,37
# 560,18.46,383,0.01,0.01,0.02,37
# 560,18.46,383,0.01,0.01,0.02,37
# 560,18.46,383,0.01,0.01,0.02,37
# 560,18.46,383,0.01,0.01,0.02,37
# 559,18.25,383,0.01,0.01,0.02,37
# 560,18.46,383,0.01,0.01,0.02,37
# 559,18.25,383,0.01,0.01,0.02,37
# 558,18.04,383,0.01,0.01,0.02,37
# 558,18.04,383,0.01,0.01,0.02,37
# 558,18.04,384,0.01,0.01,0.02,37
# 560,18.46,384,0.01,0.01,0.02,37
# 559,18.25,384,0.01,0.01,0.02,37
# 560,18.46,385,0.01,0.01,0.02,37
# 560,18.46,385,0.01,0.01,0.02,37
# 561,18.68,385,0.01,0.01,0.02,37
# 560,18.46,385,0.01,0.01,0.02,37
# 560,18.46,385,0.01,0.01,0.02,37
# 560,18.46,385,0.01,0.01,0.02,37
# 561,18.68,385,0.01,0.01,0.02,37
# 561,18.68,386,0.01,0.01,0.02,37
# 562,18.90,385,0.01,0.01,0.02,37
# 563,19.12,385,0.01,0.01,0.02,37
# 564,19.35,385,0.01,0.01,0.02,37
# 565,19.57,385,0.01,0.01,0.02,37
# 565,19.57,385,0.01,0.01,0.02,37
# 565,19.57,385,0.01,0.01,0.02,37
# 564,19.35,385,0.01,0.01,0.02,37
# 563,19.12,385,0.01,0.01,0.02,37
# 563,19.12,385,0.01,0.01,0.02,37
#